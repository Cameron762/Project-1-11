# %%
import pandas as pd
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
file = Path("../Resources/clean3data.csv")
df = pd.read_csv(file)
df.head()
# Out:
#    Unnamed: 0  Year Country Name  International Tourism Expenditures (US$)  \
# 0         652  2019      Albania                                1852000000
# 1         218  2017      Albania                                1473000000
# 2         869  2020      Albania                                 805000000
# 3         435  2018      Albania                                1750000000
# 4           1  2016      Albania                                1338000000
#
#    International Tourism Receipts (US$)  # of arrivals    GDP (US$)  \
# 0                            2458000000        6406000  15401826080
# 1                            2050000000        5118000  13019726211
# 2                            1243000000        2658000  15162734205
# 3                            2306000000        5927000  15156424061
# 4                            1821000000        4736000  11861199830
#
#    Total Population
# 0           2854191
# 1           2873457
# 2           2837849
# ...

# %%
drop1 = df.drop(["Unnamed: 0"],axis = 1)

drop1.head()
# Out:
#    Year Country Name  International Tourism Expenditures (US$)  \
# 0  2019      Albania                                1852000000
# 1  2017      Albania                                1473000000
# 2  2020      Albania                                 805000000
# 3  2018      Albania                                1750000000
# 4  2016      Albania                                1338000000
#
#    International Tourism Receipts (US$)  # of arrivals    GDP (US$)  \
# 0                            2458000000        6406000  15401826080
# 1                            2050000000        5118000  13019726211
# 2                            1243000000        2658000  15162734205
# 3                            2306000000        5927000  15156424061
# 4                            1821000000        4736000  11861199830
#
#    Total Population
# 0           2854191
# 1           2873457
# 2           2837849
# 3           2866376
# 4           2876101

# %%
drop1.count()
# Out:
# Year                                        663
# Country Name                                663
# International Tourism Expenditures (US$)    663
# International Tourism Receipts (US$)        663
# # of arrivals                               663
# GDP (US$)                                   663
# Total Population                            663
# dtype: int64

# %%
def corfunction(x,y):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x,y)
    equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    regressval = x * slope + intercept 
    plt.scatter(x,y,marker ="o",facecolors = "blue",edgecolors = "black")
    plt.plot(x,regressval,"r-")
    plt.annotate(equation,(5.8,0.8),fontsize=15,color="red")
    plt.grid
    labelx = abelx
    xlabel = labelx
    labely = abely
    ylabel = labely
    title1 = title2
    title = title1
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    print(f"The r-value is: {rvalue}")
    plt.show
    return

# %%
### Question 1 ### 
# What is the correlation between all 5 years?

# %%
drop = drop1[drop1["Country Name"] != "United States"]

# %%
# Reciepts and GDP

# %%
x = drop["GDP (US$)"]
y = drop["International Tourism Receipts (US$)"]
abelx = "GDP"
abely = "Annual Tourist Receipts"
title2 = "Reciepts and GDP"
corfunction(x,y)
plt.savefig("../png/all_years_scatter1.png")
# Out:
# The r-value is: 0.6961939251966173

# %%
# Inbound tourists and GDP

# %%
x = drop["GDP (US$)"]
y = drop["# of arrivals"]
abelx = "GDP"
abely = "Number of Annual Inbound Tourists"
title2 = "Inbound Tourists and GDP"
corfunction(x,y)
plt.savefig("../png/all_years_scatter2.png")
# Out:
# The r-value is: 0.4892631661682636
