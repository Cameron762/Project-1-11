# %%
import pandas as pd
from pathlib import Path

# %%
df = Path("Resources/2015-2020.csv")
dfdf= pd.read_csv(df)
dfdf.head(10)
# Out:
#           Country Name Country Code  \
# 0          Afghanistan          AFG
# 1              Albania          ALB
# 2              Algeria          DZA
# 3       American Samoa          ASM
# 4              Andorra          AND
# 5               Angola          AGO
# 6  Antigua and Barbuda          ATG
# 7            Argentina          ARG
# 8              Armenia          ARM
# 9                Aruba          ABW
#
#   2015 [YR2015] - GDP (current US$) [NY.GDP.MKTP.CD]  \
# 0                                    19998143635.873
# 1                                    11386853143.152
# 2                                   165979224316.667
# 3                                          673000000
# 4                                   2789881258.60547
# 5                                   87219300384.5072
# 6                                   1336692592.59259
# 7                                   594749285413.212
# 8                                   10553337527.7745
# ...
