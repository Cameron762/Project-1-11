# %%
import pandas as pd
from pathlib import Path

# %%
data_file=Path("Crime_Reports_2022.csv")
data_file_df= pd.read_csv(data_file)
# Out:
# C:\Users\Manny Dawodu\AppData\Local\Temp\ipykernel_4688\1479106923.py:2: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_file_df= pd.read_csv(data_file)

# %%
data_file_df.value_counts("Single Member Council Districts")
data_file_df.size
data_file_df.tail()
# Out:
#        Incident Number     Highest Offense Description  Highest Offense Code  \
# 87640      20223651107                     AGG ASSAULT                   402
# 87641      20228024566           BURGLARY OF RESIDENCE                   500
# 87642      20223651533      AGG ASSAULT WITH MOTOR VEH                   406
# 87643      20223651508         POSSESSION OF MARIJUANA                  1803
# 87644      20223650202  CRASH/FAIL STOP AND RENDER AID                  3604
#
#       Family Violence      Occurred Date Time Occurred Date  Occurred Time  \
# 87640               N  12/31/2022 06:55:00 PM    12/31/2022           1855
# 87641               N  12/30/2022 08:00:00 PM    12/30/2022           2000
# 87642               N  12/31/2022 11:45:00 PM    12/31/2022           2345
# 87643               N  12/31/2022 11:26:00 PM    12/31/2022           2326
# 87644               N  12/31/2022 02:46:00 AM    12/31/2022            246
#
# ...

# %%
data=data_file_df[['Incident Number','Y-coordinate','Latitude','Longitude','Single Member Council Districts']]
data
# Out:
#        Incident Number  Y-coordinate   Latitude  Longitude  \
# 0            202221104           0.0        NaN        NaN
# 1            202221365    10026946.0  30.148609 -97.794104
# 2          20228000169    10051453.0  30.217854 -97.888858
# 3            202221283    10047302.0  30.202008 -97.666881
# 4          20225000099    10135088.0  30.446297 -97.807461
# ...                ...           ...        ...        ...
# 87640      20223651107    10079537.0  30.291781 -97.720986
# 87641      20228024566    10047484.0  30.205583 -97.818846
# 87642      20223651533    10102820.0  30.355707 -97.715557
# 87643      20223651508    10070497.0  30.267279 -97.738794
# 87644      20223650202    10104694.0  30.360403 -97.693219
#
#        Single Member Council Districts
# 0                                  NaN
# 1                                  5.0
# 2                                  8.0
# 3                                  2.0
# 4                                  6.0
# ...

# %%
datas=data.dropna(how='any')
datas

# %%
data_df=datas.rename(columns={"Incident Number":"Incident-Number","Single Member Council Districts": "Districts"})
data_df
# Out:
#        Incident-Number  Y-coordinate   Latitude  Longitude  Districts
# 1            202221365    10026946.0  30.148609 -97.794104        5.0
# 2          20228000169    10051453.0  30.217854 -97.888858        8.0
# 3            202221283    10047302.0  30.202008 -97.666881        2.0
# 4          20225000099    10135088.0  30.446297 -97.807461        6.0
# 5            202220295    10117563.0  30.394960 -97.652823        7.0
# ...                ...           ...        ...        ...        ...
# 87640      20223651107    10079537.0  30.291781 -97.720986        9.0
# 87641      20228024566    10047484.0  30.205583 -97.818846        5.0
# 87642      20223651533    10102820.0  30.355707 -97.715557        7.0
# 87643      20223651508    10070497.0  30.267279 -97.738794        9.0
# 87644      20223650202    10104694.0  30.360403 -97.693219        4.0
#
# [85294 rows x 5 columns]

# %%
District_data=data_df["Districts"].value_counts()
District_data
# Out:
# Districts
# 3.0     12957
# 9.0     12664
# 4.0     11406
# 7.0     10099
# 1.0      9382
# 2.0      8528
# 5.0      6797
# 10.0     4793
# 6.0      4769
# 8.0      3899
# Name: count, dtype: int64
